# %% [markdown]
# # Visualize

# %%
# Import Basemap - used for plotting geographical locations
from mpl_toolkits.basemap import Basemap
# Import matplotlib.pyplot - used for plotting and visualization of data
import matplotlib.pyplot as plt
# Import numpy - used for creating coordinates on this plot
import numpy as np
# Import pandas - used to manage structured data in python
import pandas as pd

# %%
# Note - visualization was completed on local machine
filepath = 'FILE_PATH'

# %%
df = pd.read_csv(filepath,header=None,names=['latitude','longitude'],index_col=None,usecols=[0,1])
df.head()
# Out:
#     latitude  longitude
# 0  36.700000   3.216667
# 1  42.500000   1.516667
# 2  12.516666 -70.033330
# 3  -8.833333  13.333333
# 4  41.333332  19.800000

# %%
# Instantiate a figure
fig = plt.figure(figsize=(12,9))

m = Basemap(projection='mill',
           llcrnrlat = -90,
           urcrnrlat = 90,
           llcrnrlon = -180,
           urcrnrlon = 180,
           resolution = 'c')

m.drawcoastlines()

m.drawparallels(np.arange(-90,90,20),labels=[True,False,False,False])
m.drawmeridians(np.arange(-180,180,30),labels=[0,0,0,1])

# Create lists to be used for plotting coordinates
sites_lat_y = df['latitude'].tolist()
sites_lon_x = df['longitude'].tolist()

# Create scatter plot
m.scatter(sites_lon_x,sites_lat_y,latlon=True, color='r',s=1)

plt.title('P2 Step 3 - DBPedia Visualization', fontsize=20)
plt.savefig('device_vis')

plt.show()
# Out:
# C:\Users\aambr\AppData\Local\Continuum\anaconda3\envs\zp_gpu\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if __name__ == '__main__':
