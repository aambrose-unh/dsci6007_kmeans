# %% [markdown]
# # Visualize

# %%
# Import Basemap - used for plotting geographical locations
from mpl_toolkits.basemap import Basemap
# Import matplotlib.pyplot - used for plotting and visualization of data
import matplotlib.pyplot as plt
# Import numpy - used for creating coordinates on this plot
import numpy as np
# Import pandas - used to manage structured data in python
import pandas as pd

# %%
# Note - visualization was completed on local machine
filepath = 'FILE_PATH'

# %%
df = pd.read_csv(filepath,header=None,names=['latitude','longitude'],index_col=None,usecols=[0,1])
df.head()
# Out:
#     Latitude  Longitude
# 0  37.772540 -77.499550
# 1  42.090134 -87.689156
# 2  39.563420 -75.587530
# 3  39.453022 -87.693740
# 4  38.953800 -77.016560

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aambr\\OneDrive\\Documents\\UNH Fall 2019\\Distributed_Scalable\\Final\\notebooks'

# %%
# Instantiate a figure
fig = plt.figure(figsize=(12,9))

m = Basemap(projection='mill',
           llcrnrlat = 20,
           urcrnrlat = 55,
           llcrnrlon = -135,
           urcrnrlon = -60,
           resolution = 'c')

m.drawcoastlines()

m.drawparallels(np.arange(20,60,5),labels=[True,False,False,False])
m.drawmeridians(np.arange(-130,-60,10),labels=[0,0,0,1])

# Create lists to be used for plotting coordinates
sites_lat_y = df['latitude'].tolist()
sites_lon_x = df['longitude'].tolist()

# Create scatter plot
m.scatter(sites_lon_x,sites_lat_y,latlon=True, color='g',s=5)
# , s=500, c=colors, marker='o', alpha=1, edgecolor='k', linewidth=1, zorder=2

plt.title('P2 Step 2 - Sample Geo Visualization', fontsize=20)
# plt.savefig('device_vis')

plt.show()
# Out:
# C:\Users\aambr\AppData\Local\Continuum\anaconda3\envs\zp_gpu\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   del sys.path[0]
